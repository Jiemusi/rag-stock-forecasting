# %%
import pandas as pd

# %%
ls
# Out:
# LICENSE    README.md  config/    data/      src/

# %%
df = pd.read_csv('data/companies/NVDA.csv')

# %%
df.head()
# Out:
#   company  topic                                              title  \
# 0    NVDA    NaN  Bit Digital buys site to expand Tier-3 data op...
# 1    NVDA    NaN  Bit Digital Acquires Site In Montreal For Tier...
# 2    NVDA    NaN  Bit Digital buys Montreal site for data center...
# 3    NVDA    NaN  Nvidia History and Timeline: From GPU Maker to...
# 4    NVDA    NaN  Which AI Chip Stock Is the Better Buy for 2025...
#
#                                                  url             source  \
# 0  https://seekingalpha.com/news/4391482-bit-digi...   seekingalpha.com
# 1      https://www.rttnews.com/story.aspx?Id=3499870        rttnews.com
# 2  https://www.investing.com/news/company-news/bi...      investing.com
# 3  https://medium.com/@slingevent/nvidia-history-...         medium.com
# 4  https://finance.yahoo.com/news/ai-chip-stock-b...  finance.yahoo.com
#
#    author          published_at published_date  \
# 0     NaN  2024-12-30T15:53:44Z     2024-12-30
# ...

# %%
# print the entire description in df 
df['description'].to_string()
for i in range(len(df)):
    print(f"Description {i+1}:")
    print(df['description'][i])
    print("\n")
    if i ==6:
        break
# Out:
# Description 1:
# Bit Digital (BTBT) acquires real estate for a Tier-3 data center expansion in Montreal, costing C$61.1M. Stock sinks 7.4% on the news.
#
#
# Description 2:
# Bit Digital, Inc. (BTBT), Monday announced the acquisition of the real estate and building for a build-to-suit 5MW Tier-3 data center expansion project in Montr...
#
#
# Description 3:
# Bit Digital buys Montreal site for data center expansion
#
#
# Description 4:
# Founded as a graphics processing company, Nvidia has pivoted to designing and building accelerated computing chips that can quickly process massive amounts of d...
#
#
# Description 5:
# Nvidia is rolling out Blackwell, its next-generation AI chip architecture. Meanwhile, Broadcom is chasing what could be a $90 billion opportunity by 2027.
#
#
# Description 6:
# The past two years have been absolutely incredible for investors in Nvidia (NASDAQ: NVDA) as shares of the semiconductor giant more than doubled in both 2023 an...
#
#
# Description 7:
# ...

# %%
df['content'].to_string()
for i in range(len(df)):
    print(df['content'][i])
    print("\n")
    if i ==6:
        break
# Out:
# Bit Digital (BTBT) acquires real estate for a Tier-3 data center expansion in Montreal, costing C$61.1M. Stock sinks 7.4% on the news.
#
#
# Bit Digital, Inc. (BTBT), Monday announced the acquisition of the real estate and building for a build-to-suit 5MW Tier-3 data center expansion project in Montr...
#
#
# Bit Digital buys Montreal site for data center expansion
#
#
# Founded as a graphics processing company, Nvidia has pivoted to designing and building accelerated computing chips that can quickly process massive amounts of d...
#
#
# Nvidia is rolling out Blackwell, its next-generation AI chip architecture. Meanwhile, Broadcom is chasing what could be a $90 billion opportunity by 2027.
#
#
# The past two years have been absolutely incredible for investors in Nvidia (NASDAQ: NVDA) as shares of the semiconductor giant more than doubled in both 2023 an...
#
#
# ...
